# %%
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %%
X, y = make_classification(n_samples=100, n_features=5, n_classes=2, random_state=42)

# %%
pd.DataFrame(X)
# Out:
#            0         1         2         3         4
# 0  -0.430668  0.672873 -0.724280 -0.539630 -0.651600
# 1   0.211646 -0.843897  0.534794  0.825848  0.681953
# 2   1.092675  0.409106  1.100096 -0.942751 -0.981509
# 3   1.519901 -0.773361  1.998053  0.155132 -0.385314
# 4  -0.453901 -2.183473  0.244724  2.591239 -0.484234
# ..       ...       ...       ...       ...       ...
# 95  0.735948  1.203166  0.417673 -1.648321 -0.151785
# 96  0.846092 -1.140526  1.359706  0.861991  0.629629
# 97 -0.844677  1.643195 -1.533275 -1.411759 -1.612716
# 98 -1.282744  0.120370 -1.500776  0.450590  2.122156
# 99 -0.722168 -1.128686 -0.427958  1.560704 -1.024388
#
# [100 rows x 5 columns]

# %% [markdown]
# **Splitting the dataset into training and testing sets(80-20)**

# %%
#train, test = train_test_split(df, tes_six=ze=0.30, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.30, random_state = 42)

# %%
X_train
# Out:
# array([[-1.02754411, -0.32929388, -1.05383855,  0.82600732, -0.05952536],
#        [-1.45612516,  2.48904785, -2.52343407, -2.05832072,  1.0889506 ],
#        [-0.39769634,  1.17059844, -0.86023823, -1.09831681,  0.63391902],
#        [ 1.1374615 ,  0.24412056,  1.20852705, -0.78284083, -0.20812225],
#        [-0.73426524,  1.72251306, -1.43534875, -1.54851014,  0.50498728],
#        [-1.46361184,  0.37531604, -1.79532002,  0.25415746, -1.24778318],
#        [ 0.44205183,  1.94742094, -0.17593681, -2.3279946 , -0.62269952],
#        [-0.51103632, -1.60499282, -0.02185231,  1.98522348, -1.51936997],
#        [-0.87306613,  1.65095783, -1.56826626, -1.40735658,  0.04557184],
#        [-0.64760425,  1.34700796, -1.20592943, -1.17762637,  0.85243333],
#        [-0.84321213, -0.70426956, -0.71352532,  1.15199146, -0.33450124],
#        [ 0.65574086,  1.3939833 ,  0.25995672, -1.82037691,  0.66213067],
#        [-1.11327862,  1.89033108, -1.92487377, -1.5598485 ,  0.18645431],
#        [ 0.73594772,  1.2031659 ,  0.4176729 , -1.64832073, -0.1517851 ],
#        [-1.10644979, -0.32066954, -1.14658127,  0.85239186, -1.43014138],
#        [-0.52878508,  0.94621814, -0.9311259 , -0.79371387, -0.11473644],
#        [ 1.28131775, -0.06692233,  1.48052803, -0.50833095,  0.11351735],
#        [-1.03260487, -0.62804104, -0.95548162,  1.15466088, -0.47494531],
#        [-0.99325144,  1.69607038, -1.72067112, -1.40210053,  0.21645859],
#        [-0.05396947,  0.15985512, -0.11708689, -0.15013844,  0.82541635],
#        [ 0.04668349, -0.24878048,  0.13979096,  0.25058844,  0.61037027],
#        [ 1.51990078, -0.77336118,  1.99805321,  0.15513175, -0.3853136 ],
#        [-1.37111696,  0.50688537, -1.73597973,  0.06845616,  0.77463405],
#        [ 0.64701888,  1.44901594,  0.23085877, -1.87653774,  2.13303337],
#        [ 0.63174629, -0.88541844,  1.02703224,  0.68057323,  0.54709738],
#        [ 0.30877317, -0.56811307,  0.54914434,  0.480502  ,  0.74729361],
#        [ 0.88948365,  0.80742726,  0.73019848, -1.28568005,  0.13074058],
#        [-0.756006  ,  1.62748917, -1.42695838, -1.43483867,  2.14394409],
#        [ 0.71768635,  1.30857636,  0.36016958, -1.75518644, -1.9520878 ],
#        [-0.74717988, -1.03371682, -0.48949935,  1.46830827, -0.65332923],
#        [-0.7635164 ,  1.43140126, -1.36716377, -1.21722043, -0.73036663],
#        [-0.72216846, -1.12868571, -0.42795824,  1.56070438, -1.02438764],
#        [ 1.46098002, -0.55818081,  1.85605469, -0.05319823, -0.60021688],
#        [ 1.306542  , -0.23938468,  1.56931739, -0.3313761 ,  0.58831721],
#        [-0.69102126, -1.22532865, -0.35885569,  1.65214494,  0.91786195],
#        [-1.3731412 ,  2.40437346, -2.39955005, -2.00347738, -0.79252074],
#        [-1.13714057, -0.24038388, -1.20946429,  0.77861318,  1.26691115],
#        [ 0.97650004,  0.63067073,  0.89075877, -1.13207427,  1.44127329],
#        [-0.94116325,  1.63631177, -1.64060704, -1.36045573,  0.06428002],
#        [-0.84467713,  1.6431949 , -1.5332749 , -1.4117586 , -1.61271587],
#        [-0.74920203, -1.20727346, -0.43131517,  1.65882246, -1.20029641],
#        [ 0.55253544,  1.6253749 ,  0.06194498, -2.02632079, -0.49300093],
#        [ 0.50230075,  1.77872961, -0.04862909, -2.17105282, -0.44004449],
#        [-1.03398089, -0.56156012, -0.98021491,  1.08266027,  1.76545424],
#        [-1.2827436 ,  0.12037048, -1.50077611,  0.4505902 ,  2.1221562 ],
#        [-0.79864786, -1.07525068, -0.53355799,  1.53703587, -3.24126734],
#        [-0.32683618,  0.8834691 , -0.6795874 , -0.81680628, -0.48536355],
#        [ 0.08714206,  0.0291022 ,  0.08896214, -0.07133524,  0.08187414],
#        [-1.05463759, -0.55658056, -1.00544254,  1.08659413, -0.25256815],
#        [ 0.68720469, -1.45724683,  1.28938375,  1.28008347,  0.8496021 ],
#        [ 1.22541983,  0.01066604,  1.38991764, -0.56772453, -0.58936476],
#        [-0.97763681, -0.54561186, -0.92169432,  1.03967019,  1.6324113 ],
#        [ 0.55831966, -1.31089865,  1.09180466,  1.17869556, -0.02090159],
#        [-0.81296687,  1.85571007, -1.57127256, -1.65830375, -0.47193187],
#        [ 0.21164583, -0.84389686,  0.53479393,  0.82584805,  0.68195297],
#        [-1.69200458,  0.95057302, -2.25553963, -0.27062383, -0.70766947],
#        [-0.56603681, -1.41693293, -0.14994102,  1.80474148,  1.03246526],
#        [ 1.09267506,  0.40910605,  1.10009583, -0.94275087, -0.98150865],
#        [ 0.17593   , -1.01695056,  0.55448398,  1.03110238,  0.30729952],
#        [-0.67826129, -1.09662143, -0.38919817,  1.50575249, -1.26088395],
#        [-1.24868955,  2.35790248, -2.24181979, -2.00918545, -1.07774478],
#        [-0.14951801,  0.58846525, -0.3751207 , -0.57500215, -0.66178646],
#        [ 1.05688647,  0.40238353,  1.06173727, -0.91916686,  1.58601682],
#        [-1.19300559, -0.07873421, -1.32933233,  0.6273745 ,  0.86575519],
#        [ 1.7240021 , -1.22823431,  2.38869353,  0.55942643, -1.43586215],
#        [ 0.36205368, -0.46281432,  0.57304248,  0.34129395, -0.31026676],
#        [ 0.50047696, -1.46447269,  1.07954187,  1.3727107 ,  0.81350964],
#        [ 0.96335953,  0.65992405,  0.86561977, -1.15806823,  0.46210347],
#        [ 0.46093758,  1.89691056, -0.1368559 , -2.2813861 , -1.2378155 ],
#        [-1.29267194, -0.1173572 , -1.42922002,  0.71479373,  0.40498171]])

# %%
X_train.shape
# Out:
# (70, 5)

# %%
X_test.shape
# Out:
# (30, 5)

# %%
y_train.shape
# Out:
# (70,)

# %%
y_test.shape
# Out:
# (30,)
